# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
NAME = 'fourier.png'
mat = plt.imread(NAME)
mat1 = mat[:,:,0]

# %%
mat1.shape
# Out:
# (699, 711)

# %%
plt.imshow(mat)

# %%
fhat = np.fft.fft2(mat, axes=(2,2))

# %%
PSD = np.abs(fhat)

# %%
plt.imshow(PSD)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = 1+5j

# %%
z * np.conj(z)
# Out:
# (26+0j)

# %%
abs(z)
# Out:
# 5.0990195135927845
